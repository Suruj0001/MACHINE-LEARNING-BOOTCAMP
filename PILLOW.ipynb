# %%
from PIL import Image

# %%
pil = Image.open(r"C:\Users\suruj\machine-learning bootcamp\deeep\pht\sunset.jfif")

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=246x151 at 0x1F1804157F0>

# %%
print(pil.size)
# Out:
# (246, 151)

# %%
largeimg = pil.resize((400,300))

# %%
largeimg
# Out:
# <PIL.Image.Image image mode=RGB size=400x300 at 0x1F1F069F490>

# %%
largeimg.save(r"C:\Users\suruj\machine-learning bootcamp\deeep\pht\largeimg.jfif")

# %%
# thimg = pil.thumbnail((200,100))

# %%
pil.save(r"C:\Users\suruj\machine-learning bootcamp\deeep\pht\thgumimg.jfif")

# %%
print(largeimg.size)
# Out:
# (400, 300)

# %%
crpimg = pil.crop((0,0,20,10))

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=246x151 at 0x1F1804157F0>

# %%
crpimg
# Out:
# <PIL.Image.Image image mode=RGB size=20x10 at 0x1F180415820>

# %%
img1 = Image.open(r"C:\Users\suruj\machine-learning bootcamp\deeep\pht\suruj.jpg")

# %%
img2 = Image.open(r"C:\Users\suruj\machine-learning bootcamp\deeep\pht\suruj2.jpg")

# %%
img3 = Image.open(r"C:\Users\suruj\machine-learning bootcamp\deeep\pht\suruj3.jpg")

# %%
img1_copy = img1.copy()

# %%
img2_copy = img2.copy()

# %%
img3_copy = img3.copy()

# %%
img2_resize = img2_copy.resize((500,600))

# %%
img2_resize
# Out:
# <PIL.Image.Image image mode=RGB size=500x600 at 0x1F1F184F940>

# %%
print(img2_resize.size)
# Out:
# (500, 600)

# %%
img1_copy.paste(img2_copy , (50,50))

# %%
img1_resize = img1_copy.resize((500,700))

# %%
img1_resize
# Out:
# <PIL.Image.Image image mode=RGB size=500x700 at 0x1F1804158B0>

# %%
img1_resize.paste(img3_copy , (300,50))

# %%
img1_resize
# Out:
# <PIL.Image.Image image mode=RGB size=500x700 at 0x1F1804158B0>

# %%
img190 = img1_resize.rotate(90)

# %%
img190
# Out:
# <PIL.Image.Image image mode=RGB size=500x700 at 0x1F1804233D0>

# %%
img145 = img1_resize.rotate(45)

# %%
img145
# Out:
# <PIL.Image.Image image mode=RGB size=500x700 at 0x1F180415BB0>

# %%
img145 = img1_resize.rotate(45 , expand=True)

# %%
img145
# Out:
# <PIL.Image.Image image mode=RGB size=850x850 at 0x1F1804235E0>
