# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mtimg
import cv2

# %%
img = Image.open("road.jpg")

# %%
print(type(img))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2400x1603 at 0x1CE03F99730>

# %%
arr = np.array(img)

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
img1 = mtimg.imread("road.jpg")

# %%
plt.imshow(img1)

# %%
arr = np.asarray(img1)

# %%
arr.shape
# Out:
# (1603, 2400, 3)

# %%
plt.imshow(arr)

# %%
arr
# Out:
# array([[[ 88,  99, 153],
#         [ 88,  99, 153],
#         [ 88,  99, 153],
#         ...,
#         [201, 167, 183],
#         [201, 167, 183],
#         [203, 166, 183]],
#
#        [[ 87,  98, 152],
#         [ 87,  98, 152],
#         [ 87,  98, 152],
#         ...,
#         [200, 166, 182],
#         [200, 166, 182],
#         [200, 166, 182]],
#
#        [[ 86,  97, 151],
#         [ 86,  97, 151],
#         [ 86,  97, 151],
#         ...,
#         [198, 165, 182],
#         [198, 165, 182],
#         [198, 165, 182]],
#
#        ...,
#
#        [[ 51,  50,  66],
#         [ 52,  51,  67],
#         [ 53,  52,  68],
#         ...,
#         [132,  89,  72],
#         [131,  88,  71],
#         [131,  88,  71]],
#
#        [[ 51,  50,  66],
#         [ 52,  51,  67],
#         [ 53,  52,  68],
#         ...,
#         [132,  89,  72],
#         [131,  88,  71],
#         [131,  88,  71]],
#
#        [[ 51,  50,  66],
#         [ 52,  51,  67],
#         [ 53,  52,  68],
# ...

# %%
arr.astype(float)
# Out:
# array([[[ 88.,  99., 153.],
#         [ 88.,  99., 153.],
#         [ 88.,  99., 153.],
#         ...,
#         [201., 167., 183.],
#         [201., 167., 183.],
#         [203., 166., 183.]],
#
#        [[ 87.,  98., 152.],
#         [ 87.,  98., 152.],
#         [ 87.,  98., 152.],
#         ...,
#         [200., 166., 182.],
#         [200., 166., 182.],
#         [200., 166., 182.]],
#
#        [[ 86.,  97., 151.],
#         [ 86.,  97., 151.],
#         [ 86.,  97., 151.],
#         ...,
#         [198., 165., 182.],
#         [198., 165., 182.],
#         [198., 165., 182.]],
#
#        ...,
#
#        [[ 51.,  50.,  66.],
#         [ 52.,  51.,  67.],
#         [ 53.,  52.,  68.],
#         ...,
#         [132.,  89.,  72.],
#         [131.,  88.,  71.],
#         [131.,  88.,  71.]],
#
#        [[ 51.,  50.,  66.],
#         [ 52.,  51.,  67.],
#         [ 53.,  52.,  68.],
#         ...,
#         [132.,  89.,  72.],
#         [131.,  88.,  71.],
# ...

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>

# %%
arr.astype(int)
# Out:
# array([[[ 88,  99, 153],
#         [ 88,  99, 153],
#         [ 88,  99, 153],
#         ...,
#         [201, 167, 183],
#         [201, 167, 183],
#         [203, 166, 183]],
#
#        [[ 87,  98, 152],
#         [ 87,  98, 152],
#         [ 87,  98, 152],
#         ...,
#         [200, 166, 182],
#         [200, 166, 182],
#         [200, 166, 182]],
#
#        [[ 86,  97, 151],
#         [ 86,  97, 151],
#         [ 86,  97, 151],
#         ...,
#         [198, 165, 182],
#         [198, 165, 182],
#         [198, 165, 182]],
#
#        ...,
#
#        [[ 51,  50,  66],
#         [ 52,  51,  67],
#         [ 53,  52,  68],
#         ...,
#         [132,  89,  72],
#         [131,  88,  71],
#         [131,  88,  71]],
#
#        [[ 51,  50,  66],
#         [ 52,  51,  67],
#         [ 53,  52,  68],
#         ...,
#         [132,  89,  72],
#         [131,  88,  71],
#         [131,  88,  71]],
#
#        [[ 51,  50,  66],
#         [ 52,  51,  67],
#         [ 53,  52,  68],
# ...

# %%
img2 = cv2.imread("road.jpg")

# %%
plt.imshow(img2)

# %%
cv2.imshow("grey" , img2) 
# 0 for grey IMAGE and 1 for color image 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
rgb = cv2.cvtColor(img2 , cv2.COLOR_BGR2RGB)

# %%
plt.imshow(rgb)

# %%
pip install czifile
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import czifile

# %%
# img3 = czifile.imread("C:\Users\suruj\machine-learning bootcamp\suruj.czi")
# print(img3.shape)

# %%
# pip install apeer-ometiff-library
# from apeer_ometiff_library import io
# (pic2 , onexml) = io.read_ometiff("road.ometiff")

# %%
import cv2
import glob

# %%
path = r"C:\Users\suruj\machine-learning bootcamp\deeep\pht\*"
for file in glob.glob(path):
    print(file)
# Out:
# C:\Users\suruj\machine-learning bootcamp\deeep\pht\iron1.jpg
# C:\Users\suruj\machine-learning bootcamp\deeep\pht\ocean.jfif
# C:\Users\suruj\machine-learning bootcamp\deeep\pht\road.jpg
# C:\Users\suruj\machine-learning bootcamp\deeep\pht\sunflower.jfif
# C:\Users\suruj\machine-learning bootcamp\deeep\pht\sunset.jfif
# C:\Users\suruj\machine-learning bootcamp\deeep\pht\suruj.jpg

# %%
a = cv2.imread(file)

# %%
print(a)
# Out:
# [[[174 176 176]
#   [173 175 175]
#   [172 174 174]
#   ...
#   [164 169 170]
#   [162 167 168]
#   [162 167 168]]
#
#  [[174 176 176]
#   [172 174 174]
#   [172 174 174]
#   ...
#   [164 169 170]
#   [162 167 168]
#   [162 167 168]]
#
#  [[173 175 175]
#   [172 174 174]
#   [172 174 174]
#   ...
#   [165 170 171]
#   [163 168 169]
#   [162 167 168]]
#
#  ...
#
#  [[138 142 143]
#   [143 147 148]
#   [146 150 151]
#   ...
#   [ 82  91  95]
#   [ 85  91  96]
#   [ 84  90  95]]
#
#  [[138 143 142]
#   [144 149 148]
#   [145 149 150]
#   ...
#   [ 83  92  96]
#   [ 84  90  95]
#   [ 83  89  94]]
#
#  [[144 149 148]
#   [148 153 152]
#   [145 149 150]
#   ...
#   [ 83  92  96]
#   [ 86  92  97]
#   [ 85  91  96]]]

# %%
c = cv2.cvtColor(a , cv2.COLOR_BGR2RGB)

# %%
cv2.imshow("windows" , c)
cv2.waitKey(0)
cv2.destroyAllWindows()
